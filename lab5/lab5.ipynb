# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)


def chunks(seq, size):
    return (seq[pos : pos + size] for pos in range(0, len(seq), size))


def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = (
                examples[r, c] - ex_min
            ) / (ex_max - ex_min)

    plt.matshow(img_matrix, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()
digits = np.reshape(mnist.train_images()[: 12 * 24], newshape=(12, 24, 28, 28))
tiles(digits)
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/671394299.py:4: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   digits = np.reshape(mnist.train_images()[: 12 * 24], newshape=(12, 24, 28, 28))

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))


class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum

        self.reset()

    def reset(self):
        self.W = np.random.normal(
            scale=0.01, size=(self.visible_size + 1, self.hidden_size + 1)
        ).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size + 1, self.hidden_size + 1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]

    # Initialize matrices:
    # - visible: Will store reconstructions (without bias)
    # - hidden: Hidden layer activations (with bias)
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # 1. Encode: Compute hidden probabilities and sample binary states
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(
        hidden.shape[0], hidden.shape[1] - 1
    )

    # 2. Decode: Reconstruct visible layer (no sampling, just probabilities)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count
    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")


def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch), end="\t")

        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time

        error = reconstuction_error(rbm, monitoring_set)
        print(
            "\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(
                elapsed, error
            )
        )

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    # Inicjalizacja warstw aktywacji
    # - positive_visible: Original input data (with bias term)
    # - negative_visible: Will store reconstructed visible layer (initialized to zeros + bias)
    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    # Initialize hidden layer matrices:
    # - positive_hidden: Hidden activations for positive phase (initialized to zeros + bias)
    # - negative_hidden: Hidden activations for negative phase (initialized to zeros + bias)
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # Pozytywna faza: propagacja do warstwy ukrytej
    # ===== POSITIVE PHASE =====
    # Compute hidden layer probabilities given visible data (forward pass)
    # - rbm.W[:, :-1] excludes the bias weights for hidden units
    # - sigmoid converts logits to probabilities
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])

    # Compute positive gradient (data-dependent statistics)
    # - This is E[vh^T] under the data distribution
    # - Divided by batch size to get average gradient
    pos_grad = (positive_visible.T @ positive_hidden) / observations_count

    # Negatywna faza: próbkujemy przez Gibbs sampling
    # ===== NEGATIVE PHASE (Gibbs Sampling) =====
    # Initial Gibbs sampling step:
    # 1. Sample hidden units given visible data (using probabilities from positive phase)
    #    - positive_hidden[:, :-1] are probabilities (from sigmoid)
    #    - rand() generates uniform random numbers for thresholding
    #    - '>' performs Bernoulli sampling

    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(
        positive_hidden.shape[0], positive_hidden.shape[1] - 1
    )

    # 2. Sample visible units given hidden samples
    #    - rbm.W[:-1, :].T is the transpose of weights (excluding visible bias)
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(
        *negative_visible[:, :-1].shape
    )

    # Additional Gibbs steps (if k > 1)
    for _ in range(k - 1):
        # Sample hidden units again given reconstructed visible units
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(
            *negative_hidden[:, :-1].shape
        )
        # Sample visible units again given new hidden units
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(
            *negative_visible[:, :-1].shape
        )

    # Ostateczna aktualizacja dla negatywnej fazy (bez samplowania) do policzenia gradientu
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    # Compute negative gradient
    # - This is E[vh^T] under the model's distribution
    neg_grad = (negative_visible.T @ negative_hidden) / observations_count

    # Aktualizacja wag RBM
    # ===== WEIGHT UPDATE =====
    # Update rule: ΔW = η*(positive_gradient - negative_gradient)
    # - Learning rate (η) scales the update
    # - pos_grad pushes weights toward data distribution
    # - neg_grad pulls weights away from model distribution
    gradient = pos_grad - neg_grad
    learning_rate = rbm.learning_rate
    momentum = rbm.momentum

    rbm.M = momentum * rbm.M + learning_rate * gradient
    rbm.W += rbm.M

# %%
import time

DATASET_SIZE = 20000  # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE * DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(
    mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
)
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/1757742224.py:11: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   dataset = np.reshape(

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/3631771926.py:2: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# Epoch 0:	#####################################################	elapsed: 0.13s, reconstruction error: 26.43
# Epoch 1:	#####################################################	elapsed: 0.16s, reconstruction error: 21.38
# Epoch 2:	#####################################################	elapsed: 0.14s, reconstruction error: 18.80
# Epoch 3:	#####################################################	elapsed: 0.13s, reconstruction error: 17.32
# Epoch 4:	#####################################################	elapsed: 0.15s, reconstruction error: 16.25
# Epoch 5:	#####################################################	elapsed: 0.15s, reconstruction error: 15.01
# Epoch 6:	#####################################################	elapsed: 0.15s, reconstruction error: 14.06
# Epoch 7:	#####################################################	elapsed: 0.14s, reconstruction error: 13.22
# Epoch 8:	#####################################################	elapsed: 0.14s, reconstruction error: 12.91
# Epoch 9:	#####################################################	elapsed: 0.15s, reconstruction error: 12.51
# Epoch 10:	#####################################################	elapsed: 0.14s, reconstruction error: 12.09
# Epoch 11:	#####################################################	elapsed: 0.15s, reconstruction error: 11.99
# Epoch 12:	#####################################################	elapsed: 0.14s, reconstruction error: 11.77
# Epoch 13:	#####################################################	elapsed: 0.14s, reconstruction error: 11.61
# Epoch 14:	#####################################################	elapsed: 0.14s, reconstruction error: 11.59
# Epoch 15:	#####################################################	elapsed: 0.14s, reconstruction error: 11.19
# Epoch 16:	#####################################################	elapsed: 0.15s, reconstruction error: 11.25
# Epoch 17:	#####################################################	elapsed: 0.14s, reconstruction error: 11.31
# Epoch 18:	#####################################################	elapsed: 0.14s, reconstruction error: 11.29
# Epoch 19:	#####################################################	elapsed: 0.14s, reconstruction error: 11.08
# Epoch 20:	#####################################################	elapsed: 0.15s, reconstruction error: 11.12
# Epoch 21:	#####################################################	elapsed: 0.14s, reconstruction error: 11.02
# Epoch 22:	#####################################################	elapsed: 0.14s, reconstruction error: 10.83
# Epoch 23:	#####################################################	elapsed: 0.14s, reconstruction error: 10.90
# Epoch 24:	#####################################################	elapsed: 0.14s, reconstruction error: 10.74
# Epoch 25:	#####################################################	elapsed: 0.14s, reconstruction error: 10.95
# Epoch 26:	#####################################################	elapsed: 0.14s, reconstruction error: 10.62
# Epoch 27:	#####################################################	elapsed: 0.15s, reconstruction error: 10.65
# Epoch 28:	#####################################################	elapsed: 0.16s, reconstruction error: 10.61
# Epoch 29:	#####################################################	elapsed: 0.14s, reconstruction error: 10.78
# Epoch 30:	#####################################################	elapsed: 0.15s, reconstruction error: 10.47
# Epoch 31:	#####################################################	elapsed: 0.14s, reconstruction error: 10.46
# Epoch 32:	#####################################################	elapsed: 0.14s, reconstruction error: 10.45
# Epoch 33:	#####################################################	elapsed: 0.14s, reconstruction error: 10.52
# Epoch 34:	#####################################################	elapsed: 0.14s, reconstruction error: 10.51
# Epoch 35:	#####################################################	elapsed: 0.14s, reconstruction error: 10.33
# Epoch 36:	#######################################
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/4233723373.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-matrix))
# ##############	elapsed: 0.14s, reconstruction error: 10.42
# Epoch 37:	#####################################################	elapsed: 0.14s, reconstruction error: 10.50
# Epoch 38:	#####################################################	elapsed: 0.14s, reconstruction error: 10.38
# Epoch 39:	#####################################################	elapsed: 0.14s, reconstruction error: 10.33
# Epoch 40:	#####################################################	elapsed: 0.14s, reconstruction error: 10.39
# Epoch 41:	#####################################################	elapsed: 0.13s, reconstruction error: 10.31
# Epoch 42:	#####################################################	elapsed: 0.14s, reconstruction error: 10.15
# Epoch 43:	#####################################################	elapsed: 0.13s, reconstruction error: 10.21
# Epoch 44:	#####################################################	elapsed: 0.14s, reconstruction error: 10.32
# Epoch 45:	#####################################################	elapsed: 0.13s, reconstruction error: 10.45
# Epoch 46:	#####################################################	elapsed: 0.13s, reconstruction error: 10.40
# Epoch 47:	#####################################################	elapsed: 0.13s, reconstruction error: 10.30
# Epoch 48:	#####################################################	elapsed: 0.14s, reconstruction error: 10.34
# Epoch 49:	#####################################################	elapsed: 0.13s, reconstruction error: 10.34
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible


def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    propagated = propagate_up(dbn, layers_count, visible=minibatch)
    return reconstuction_error(dbn[layers_count], propagated)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (
            hidden[:, :-1] > rand(observations_count, rbm.hidden_size)
        ).astype(np.float32)

        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (
                visible[:, :-1] > rand(observations_count, rbm.visible_size)
            ).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    sample = propagate_up(dbn, layer_idx, minibatch)
    sample = sample_rbm(dbn[layer_idx], sample, steps)
    sample = propagate_down(dbn, layer_idx, sample)
    return sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch), end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8

        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time

        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print(
            "\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(
                elapsed, error
            )
        )

print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 0.18s, reconstruction error: 24.53
# Epoch 1:	#####################################################	elapsed: 0.16s, reconstruction error: 19.20
# Epoch 2:	#####################################################	elapsed: 0.18s, reconstruction error: 16.75
# Epoch 3:	#####################################################	elapsed: 0.17s, reconstruction error: 15.18
# Epoch 4:	#####################################################	elapsed: 0.17s, reconstruction error: 14.08
# Epoch 5:	#####################################################	elapsed: 0.18s, reconstruction error: 12.89
# Epoch 6:	#####################################################	elapsed: 0.18s, reconstruction error: 12.06
# Epoch 7:	#####################################################	elapsed: 0.18s, reconstruction error: 11.32
# Epoch 8:	#####################################################	elapsed: 0.18s, reconstruction error: 10.64
# Epoch 9:	#####################################################	elapsed: 0.17s, reconstruction error: 10.46
# Epoch 10:	#####################################################	elapsed: 0.17s, reconstruction error: 10.38
# Epoch 11:	#####################################################	elapsed: 0.17s, reconstruction error: 10.07
# Epoch 12:	#####################################################	elapsed: 0.19s, reconstruction error: 9.95
# Epoch 13:	#####################################################	elapsed: 0.17s, reconstruction error: 9.77
# Epoch 14:	#####################################################	elapsed: 0.18s, reconstruction error: 9.62
# Epoch 15:	#####################################################	elapsed: 0.18s, reconstruction error: 9.41
# Epoch 16:	#####################################################	elapsed: 0.19s, reconstruction error: 9.37
# Epoch 17:	#####################################################	elapsed: 0.18s, reconstruction error: 9.39
# Epoch 18:	#####################################################	elapsed: 0.17s, reconstruction error: 9.22
# Epoch 19:	#####################################################	elapsed: 0.19s, reconstruction error: 9.11
# Epoch 20:	#####################################################	elapsed: 0.18s, reconstruction error: 9.25
# Epoch 21:	#####################################################	elapsed: 0.18s, reconstruction error: 9.05
# Epoch 22:	#####################################################	elapsed: 0.16s, reconstruction error: 9.07
# Epoch 23:	#####################################################	elapsed: 0.17s, reconstruction error: 8.98
# Epoch 24:	#####################################################	elapsed: 0.18s, reconstruction error: 8.93
# Epoch 25:	#####################################################	elapsed: 0.17s, reconstruction error: 8.82
# Epoch 26:	#####################################################	elapsed: 0.17s, reconstruction error: 8.79
# Epoch 27:	#####################################################	elapsed: 0.19s, reconstruction error: 8.69
# Epoch 28:	#####################################################	elapsed: 0.17s, reconstruction error: 8.63
# Epoch 29:	#####################################################	elapsed: 0.17s, reconstruction error: 8.83
# Epoch 30:	#####################################################	elapsed: 0.18s, reconstruction error: 8.65
# Epoch 31:	#####################################################	elapsed: 0.20s, reconstruction error: 8.64
# Epoch 32:	#####################################################	elapsed: 0.17s, reconstruction error: 8.58
# Epoch 33:	#####################################################	elapsed: 0.16s, reconstruction error: 8.78
# Epoch 34:	#####################################################	elapsed: 0.16s, reconstruction error: 8.54
# Epoch 35:	#####################################################	elapsed: 0.18s, reconstruction error: 8.63
# Epoch 36:	#####################################################	elapsed: 0.18s, reconstruction error: 8.57
# Epoch 37:	#####################################################	elapsed: 0.16s, reconstruction error: 8.55
# Epoch 38:	#####################################################	elapsed: 0.16s, reconstruction error: 8.49
# Epoch 39:	#####################################################	elapsed: 0.16s, reconstruction error: 8.54
# Epoch 40:	#####################################################	elapsed: 0.16s, reconstruction error: 8.45
# Epoch 41:	#####################################################	elapsed: 0.17s, reconstruction error: 8.32
# Epoch 42:	#####################################################	elapsed: 0.17s, reconstruction error: 8.50
# Epoch 43:	#####################################################	elapsed: 0.16s, reconstruction error: 8.35
# Epoch 44:	#####################################################	elapsed: 0.16s, reconstruction error: 8.32
# Epoch 45:	#####################################################	elapsed: 0.17s, reconstruction error: 8.34
# Epoch 46:	#####################################################	elapsed: 0.16s, reconstruction error: 8.25
# Epoch 47:	#####################################################	elapsed: 0.16s, reconstruction error: 8.43
# Epoch 48:	#####################################################	elapsed: 0.16s, reconstruction error: 8.26
# Epoch 49:	#####################################################	elapsed: 0.16s, reconstruction error: 8.46
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.08s, reconstruction error: 14.16
# Epoch 1:	#####################################################	elapsed: 0.08s, reconstruction error: 10.87
# Epoch 2:	#####################################################	elapsed: 0.08s, reconstruction error: 9.02
# Epoch 3:	#####################################################	elapsed: 0.08s, reconstruction error: 8.18
# Epoch 4:	#####################################################	elapsed: 0.08s, reconstruction error: 7.55
# Epoch 5:	#####################################################	elapsed: 0.08s, reconstruction error: 6.84
# Epoch 6:	#####################################################	elapsed: 0.08s, reconstruction error: 6.20
# Epoch 7:	#####################################################	elapsed: 0.08s, reconstruction error: 5.85
# Epoch 8:	#####################################################	elapsed: 0.08s, reconstruction error: 5.62
# Epoch 9:	#####################################################	elapsed: 0.08s, reconstruction error: 5.28
# Epoch 10:	#####################################################	elapsed: 0.08s, reconstruction error: 5.24
# Epoch 11:	#####################################################	elapsed: 0.08s, reconstruction error: 5.12
# Epoch 12:	#####################################################	elapsed: 0.08s, reconstruction error: 5.04
# Epoch 13:	#####################################################	elapsed: 0.08s, reconstruction error: 4.96
# Epoch 14:	#####################################################	elapsed: 0.08s, reconstruction error: 4.93
# Epoch 15:	#####################################################	elapsed: 0.09s, reconstruction error: 4.63
# Epoch 16:	#####################################################	elapsed: 0.08s, reconstruction error: 4.85
# Epoch 17:	#####################################################	elapsed: 0.08s, reconstruction error: 4.74
# Epoch 18:	#####################################################	elapsed: 0.08s, reconstruction error: 4.52
# Epoch 19:	#####################################################	elapsed: 0.08s, reconstruction error: 4.56
# Epoch 20:	#####################################################	elapsed: 0.08s, reconstruction error: 4.50
# Epoch 21:	#####################################################	elapsed: 0.08s, reconstruction error: 4.46
# Epoch 22:	#####################################################	elapsed: 0.08s, reconstruction error: 4.36
# Epoch 23:	#####################################################	elapsed: 0.08s, reconstruction error: 4.42
# Epoch 24:	#####################################################	elapsed: 0.08s, reconstruction error: 4.48
# Epoch 25:	#####################################################	elapsed: 0.08s, reconstruction error: 4.30
# Epoch 26:	#####################################################	elapsed: 0.08s, reconstruction error: 4.32
# Epoch 27:	#####################################################	elapsed: 0.08s, reconstruction error: 4.38
# Epoch 28:	#####################################################	elapsed: 0.08s, reconstruction error: 4.33
# Epoch 29:	#####################################################	elapsed: 0.08s, reconstruction error: 4.30
# Epoch 30:	#####################################################	elapsed: 0.08s, reconstruction error: 4.28
# Epoch 31:	#####################################################	elapsed: 0.08s, reconstruction error: 4.18
# Epoch 32:	#####################################################	elapsed: 0.08s, reconstruction error: 4.24
# Epoch 33:	#####################################################	elapsed: 0.08s, reconstruction error: 4.21
# Epoch 34:	#####################################################	elapsed: 0.08s, reconstruction error: 4.13
# Epoch 35:	#####################################################	elapsed: 0.08s, reconstruction error: 4.04
# Epoch 36:	#####################################################	elapsed: 0.08s, reconstruction error: 4.17
# Epoch 37:	#####################################################	elapsed: 0.08s, reconstruction error: 4.11
# Epoch 38:	#####################################################	elapsed: 0.08s, reconstruction error: 4.17
# Epoch 39:	#####################################################	elapsed: 0.08s, reconstruction error: 4.18
# Epoch 40:	#####################################################	elapsed: 0.08s, reconstruction error: 4.15
# Epoch 41:	#####################################################	elapsed: 0.08s, reconstruction error: 4.07
# Epoch 42:	#####################################################	elapsed: 0.08s, reconstruction error: 4.11
# Epoch 43:	#####################################################	elapsed: 0.08s, reconstruction error: 4.11
# Epoch 44:	#####################################################	elapsed: 0.08s, reconstruction error: 4.02
# Epoch 45:	#####################################################	elapsed: 0.08s, reconstruction error: 4.10
# Epoch 46:	#####################################################	elapsed: 0.08s, reconstruction error: 4.04
# Epoch 47:	#####################################################	elapsed: 0.08s, reconstruction error: 4.07
# Epoch 48:	#####################################################	elapsed: 0.08s, reconstruction error: 3.96
# Epoch 49:	#####################################################	elapsed: 0.09s, reconstruction error: 4.06
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 0.10s, reconstruction error: 10.35
# Epoch 1:	#####################################################	elapsed: 0.10s, reconstruction error: 7.52
# Epoch 2:	#####################################################	elapsed: 0.10s, reconstruction error: 6.29
# Epoch 3:	#####################################################	elapsed: 0.09s, reconstruction error: 5.62
# Epoch 4:	#####################################################	elapsed: 0.19s, reconstruction error: 5.13
# Epoch 5:	#####################################################	elapsed: 0.20s, reconstruction error: 4.64
# Epoch 6:	#####################################################	elapsed: 0.10s, reconstruction error: 4.08
# Epoch 7:	#####################################################	elapsed: 0.09s, reconstruction error: 3.89
# Epoch 8:	#####################################################	elapsed: 0.10s, reconstruction error: 3.79
# Epoch 9:	#####################################################	elapsed: 0.10s, reconstruction error: 3.59
# Epoch 10:	#####################################################	elapsed: 0.10s, reconstruction error: 3.48
# Epoch 11:	#####################################################	elapsed: 0.10s, reconstruction error: 3.45
# Epoch 12:	#####################################################	elapsed: 0.10s, reconstruction error: 3.39
# Epoch 13:	#####################################################	elapsed: 0.10s, reconstruction error: 3.41
# Epoch 14:	#####################################################	elapsed: 0.10s, reconstruction error: 3.34
# Epoch 15:	#####################################################	elapsed: 0.09s, reconstruction error: 3.33
# Epoch 16:	#####################################################	elapsed: 0.10s, reconstruction error: 3.18
# Epoch 17:	#####################################################	elapsed: 0.10s, reconstruction error: 3.19
# Epoch 18:	#####################################################	elapsed: 0.10s, reconstruction error: 3.16
# Epoch 19:	#####################################################	elapsed: 0.10s, reconstruction error: 3.14
# Epoch 20:	#####################################################	elapsed: 0.10s, reconstruction error: 3.13
# Epoch 21:	#####################################################	elapsed: 0.10s, reconstruction error: 3.12
# Epoch 22:	#####################################################	elapsed: 0.10s, reconstruction error: 3.01
# Epoch 23:	#####################################################	elapsed: 0.10s, reconstruction error: 3.03
# Epoch 24:	#####################################################	elapsed: 0.10s, reconstruction error: 3.13
# Epoch 25:	#####################################################	elapsed: 0.10s, reconstruction error: 3.10
# Epoch 26:	#####################################################	elapsed: 0.09s, reconstruction error: 2.95
# Epoch 27:	#####################################################	elapsed: 0.10s, reconstruction error: 2.91
# Epoch 28:	#####################################################	elapsed: 0.09s, reconstruction error: 2.94
# Epoch 29:	#####################################################	elapsed: 0.10s, reconstruction error: 2.98
# Epoch 30:	#####################################################	elapsed: 0.09s, reconstruction error: 3.00
# Epoch 31:	#####################################################	elapsed: 0.10s, reconstruction error: 2.97
# Epoch 32:	#####################################################	elapsed: 0.10s, reconstruction error: 2.93
# Epoch 33:	#####################################################	elapsed: 0.10s, reconstruction error: 3.06
# Epoch 34:	#####################################################	elapsed: 0.10s, reconstruction error: 2.95
# Epoch 35:	#####################################################	elapsed: 0.10s, reconstruction error: 2.88
# Epoch 36:	#####################################################	elapsed: 0.10s, reconstruction error: 2.90
# Epoch 37:	#####################################################	elapsed: 0.10s, reconstruction error: 2.99
# Epoch 38:	#####################################################	elapsed: 0.10s, reconstruction error: 3.01
# Epoch 39:	#####################################################	elapsed: 0.10s, reconstruction error: 2.93
# Epoch 40:	#####################################################	elapsed: 0.10s, reconstruction error: 2.94
# Epoch 41:	#####################################################	elapsed: 0.10s, reconstruction error: 2.79
# Epoch 42:	#####################################################	elapsed: 0.10s, reconstruction error: 2.91
# Epoch 43:	#####################################################	elapsed: 0.10s, reconstruction error: 2.93
# Epoch 44:	#####################################################	elapsed: 0.10s, reconstruction error: 2.88
# Epoch 45:	#####################################################	elapsed: 0.10s, reconstruction error: 2.90
# Epoch 46:	#####################################################	elapsed: 0.10s, reconstruction error: 2.87
# Epoch 47:	#####################################################	elapsed: 0.09s, reconstruction error: 2.85
# Epoch 48:	#####################################################	elapsed: 0.10s, reconstruction error: 2.84
# Epoch 49:	#####################################################	elapsed: 0.10s, reconstruction error: 2.89
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[: 8 * 16])
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/3281778931.py:3: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %%
draw_layer_samples(dbn, 1, monitoring_set[: 8 * 16])
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/3281778931.py:3: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %%
draw_layer_samples(dbn, 2, monitoring_set[: 8 * 16])
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_11599/3281778931.py:3: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))
