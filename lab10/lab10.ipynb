# %%
import time

import matplotlib.pyplot as plt
import numpy as np

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)


def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)


def chunks(seq, size):
    return (seq[pos : pos + size] for pos in range(0, len(seq), size))


def as_matrix(vector):
    return np.reshape(vector, (-1, 1))


def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = (
                examples[r, c] - ex_min
            ) / (ex_max - ex_min)

    plt.matshow(img_matrix, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()


def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)


def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations


def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %%
def gaussian(batch, stochastic=False):
    if stochastic:
        return np.random.normal(batch, 1)
    else:
        return batch


def gaussian_derivative(batch):
    return ones(*batch.shape)

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

digits = np.reshape(mnist.train_images()[: 12 * 24], newshape=(12, 24, 28, 28))
tiles(digits)
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/2982779152.py:5: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   digits = np.reshape(mnist.train_images()[: 12 * 24], newshape=(12, 24, 28, 28))

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(
        self,
        visible_size,
        hidden_size,
        visible_act_func,
        hidden_act_func,
        learning_rate,
        momentum,
        l2_penalty,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.l2_penalty = l2_penalty

        self.reset()

    def reset(self):
        self.W = np.random.normal(
            scale=0.01, size=(self.visible_size + 1, self.hidden_size + 1)
        ).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size + 1, self.hidden_size + 1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(
            negative_hidden @ rbm.W[:-1, :].T, stochastic=True
        )
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (
        (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    )
    rbm.M -= (
        (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden
    )

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = (
            rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]
        )

    rbm.W += rbm.M


def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = hidden[:, :-1] > rand(observations_count, rbm.hidden_size)

    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))

    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count

    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible


def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(
            dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :]))
        )
    return hidden


def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstuction_error(dbn[layer_idx], propagated)
    return error


def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0:
            print("#", end="")


def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch + 1), end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print(
                "\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(
                    elapsed, error
                )
            )

# %% [markdown]
# # Autoencoder training

# %%
class Layer:
    def __init__(
        self,
        visible_size,
        hidden_size,
        activation_fun,
        d_activation_fun,
        learning_rate,
        momentum,
        l2_penalty,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.l2_penalty = l2_penalty

        self.reset()

    def reset(self):
        self.W = np.random.normal(
            scale=0.01, size=(self.visible_size + 1, self.hidden_size)
        ).astype(np.float32)
        self.W[-1, :] = 0.0

        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size + 1, self.hidden_size)

# %%
def forward_pass(ae, batch, compute_derivatives):
    visible = batch

    for layer_idx, layer in enumerate(ae):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))

        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)

        visible = layer.activations

    return visible[:, :-1]


def error_backpropagate(ae, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (
                layer.deltas @ layer.W[:-1, :].T
            ) * prev_layer.d_activations
        else:
            visible = batch

        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (
            visible.T @ layer.deltas
        )

        if layer.l2_penalty > 0:
            layer.M[:-1, :] = (
                layer.M[:-1, :]
                - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
            )

        layer.W += layer.M

# %% [markdown]
# ### Cross entropy cost

# %% [markdown]
# Implement cross entropy cost for deep AE. To this end:
#
# - calculate the cross entropy cost between pixels in the input batch and their reconstructions,
# - sum the cross entropy cost over all pixels and all observations in the minibatch,
# - return average cost per input observation.

# %%
def xentropy(batch, reconstructions):
    observations_count = batch.shape[0]

    return (
        -np.sum(
            batch * np.log(reconstructions) + (1 - batch) * np.log(1 - reconstructions)
        )
        / observations_count
    )

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)

    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)

        # Gradient of the cross entropy cost wrt the deep AE output is not implemented
        ae[-1].deltas = reconstructions - batch[:, :-1]

        error_backpropagate(ae, batch)

        if batch_idx % round(batches_limit / 40) == 0:
            print("#", end="")

# %%
def run_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch + 1), end="\t")

        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %% [markdown]
# ### Initializing AE with DBN weights
#
# Implement initialization of AE weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the AE weights (and biases) are **copies** of the DBN weights (and biases). You can use `np.copy(...)` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_ae(ae, dbn):
    assert len(ae) == 2 * len(dbn)

    ae_idx = 0

    for layer_idx in range(len(dbn)):
        ae[ae_idx].W = np.copy(dbn[layer_idx].W[:, :-1])
        ae_idx += 1

    for layer_idx in range(len(dbn) - 1, -1, -1):
        ae[ae_idx].W = np.copy(dbn[layer_idx].W[:-1, :].T)
        ae_idx += 1

# %% [markdown]
# # Autoencoder for MNIST digits

# %%
DATASET_SIZE = 10000  # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(
    mnist_train_images[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
)
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(
    mnist_train_images.shape[0], 512, replace=False
)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(
    mnist_test_images, newshape=(-1, DIGIT_SIZE * DIGIT_SIZE)
)
mnist_test_images = append_ones(mnist_test_images)
# Out:
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/35568406.py:9: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   mnist_train_images = np.reshape(
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/35568406.py:22: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   mnist_test_images = np.reshape(

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE * DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.9
L2_PENALTY = 0.0002

# %%
from IPython.core.display import HTML


def compare_results(
    ae, dbn, train_set, validation_set, monitoring_set, batch_size, epochs_count
):
    for layer in ae:
        layer.reset()

    display(HTML("<h3>Plain AE training</h3>"))
    run_ae_training(ae, train_set, validation_set, batch_size, epochs_count)

    display(HTML("<h3>Input layer filters in the plain AE</h3>"))
    draw_layer_filters(ae[0])

    display(HTML("<h3>Input minibatch</h3>"))
    tiles(np.reshape(validation_set[: 8 * 24, :-1], newshape=(8, 24, 28, 28)))

    display(HTML("<h3>Plain AE reconstructions</h3>"))
    ae_reconstructions = np.reshape(
        forward_pass(ae, validation_set[: 8 * 24], False), newshape=(8, 24, 28, 28)
    )
    tiles(ae_reconstructions)

    display(HTML("<h3>DBN training</h3>"))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)

    for layer in ae:
        layer.reset()

    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(
        forward_pass(ae, validation_set[: 8 * 24, :], False), newshape=(8, 24, 28, 28)
    )
    dbn_rec_cost = xentropy(
        validation_set[:, :-1], forward_pass(ae, validation_set, False)
    )

    display(HTML("<h3>Finetuning pretrained AE</h3>"))

    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set, batch_size, epochs_count)

    display(HTML("<h3>First layer filters in the DBN</h3>"))
    draw_rbm_filters(dbn[0])

    display(HTML("<h3>Input layer filters in the pretrained & finetuned AE</h3>"))
    draw_layer_filters(ae[0])

    display(HTML("<h3>Input minibatch</h3>"))
    tiles(np.reshape(validation_set[: 8 * 24, :-1], newshape=(8, 24, 28, 28)))

    display(HTML("<h3>Pretrained AE reconstructions</h3>"))
    tiles(dbn_reconstructions)

    display(HTML("<h3>Finetuned AE reconstructions</h3>"))
    ae_reconstructions = np.reshape(
        forward_pass(ae, validation_set[: 8 * 24], False), newshape=(8, 24, 28, 28)
    )
    tiles(ae_reconstructions)

# %% [markdown]
# ### Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY),
]


ae = [
    Layer(
        VISIBLE_LAYER_SIZE,
        256,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    Layer(
        256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        10, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        256,
        VISIBLE_LAYER_SIZE,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
]

compare_results(
    ae,
    dbn,
    mnist_train_images,
    mnist_test_images,
    monitoring_set,
    BATCH_SIZE,
    EPOCHS_COUNT,
)
# Out:
# <h3>Plain AE training</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:5: RuntimeWarning: divide by zero encountered in matmul
#   z = visible @ layer.W
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:5: RuntimeWarning: overflow encountered in matmul
#   z = visible @ layer.W
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:5: RuntimeWarning: invalid value encountered in matmul
#   z = visible @ layer.W
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:25: RuntimeWarning: divide by zero encountered in matmul
#   layer.deltas @ layer.W[:-1, :].T
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:25: RuntimeWarning: overflow encountered in matmul
#   layer.deltas @ layer.W[:-1, :].T
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:25: RuntimeWarning: invalid value encountered in matmul
#   layer.deltas @ layer.W[:-1, :].T
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:32: RuntimeWarning: divide by zero encountered in matmul
#   visible.T @ layer.deltas
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:32: RuntimeWarning: overflow encountered in matmul
#   visible.T @ layer.deltas
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/54097569.py:32: RuntimeWarning: invalid value encountered in matmul
#   visible.T @ layer.deltas
# Epoch 1:	########################################	elapsed: 0.12s, cross-entropy: 206.27
# Epoch 2:	########################################	elapsed: 0.13s, cross-entropy: 206.18
# Epoch 3:	########################################	elapsed: 0.14s, cross-entropy: 206.16
# Epoch 4:	########################################	elapsed: 0.12s, cross-entropy: 206.15
# Epoch 5:	########################################	elapsed: 0.12s, cross-entropy: 206.14
# Epoch 6:	########################################	elapsed: 0.13s, cross-entropy: 206.13
# Epoch 7:	########################################	elapsed: 0.13s, cross-entropy: 206.13
# Epoch 8:	########################################	elapsed: 0.13s, cross-entropy: 206.12
# Epoch 9:	########################################	elapsed: 0.13s, cross-entropy: 206.12
# Epoch 10:	########################################	elapsed: 0.14s, cross-entropy: 206.11
# Epoch 11:	########################################	elapsed: 0.13s, cross-entropy: 206.11
# Epoch 12:	########################################	elapsed: 0.14s, cross-entropy: 206.10
# Epoch 13:	########################################	elapsed: 0.15s, cross-entropy: 206.10
# Epoch 14:	########################################	elapsed: 0.15s, cross-entropy: 206.09
# Epoch 15:	########################################	elapsed: 0.13s, cross-entropy: 206.09
# Epoch 16:	########################################	elapsed: 0.16s, cross-entropy: 206.09
# Epoch 17:	########################################	elapsed: 0.18s, cross-entropy: 206.08
# Epoch 18:	########################################	elapsed: 0.14s, cross-entropy: 206.08
# Epoch 19:	########################################	elapsed: 0.15s, cross-entropy: 206.08
# Epoch 20:	########################################	elapsed: 0.14s, cross-entropy: 206.07
# Epoch 21:	########################################	elapsed: 0.13s, cross-entropy: 206.07
# Epoch 22:	########################################	elapsed: 0.15s, cross-entropy: 206.07
# Epoch 23:	########################################	elapsed: 0.14s, cross-entropy: 206.07
# Epoch 24:	########################################	elapsed: 0.14s, cross-entropy: 206.06
# Epoch 25:	########################################	elapsed: 0.14s, cross-entropy: 206.06
# Epoch 26:	########################################	elapsed: 0.15s, cross-entropy: 206.06
# Epoch 27:	########################################	elapsed: 0.14s, cross-entropy: 206.06
# Epoch 28:	########################################	elapsed: 0.15s, cross-entropy: 206.05
# Epoch 29:	########################################	elapsed: 0.14s, cross-entropy: 206.05
# Epoch 30:	########################################	elapsed: 0.13s, cross-entropy: 206.05
# Epoch 31:	########################################	elapsed: 0.14s, cross-entropy: 206.05
# Epoch 32:	########################################	elapsed: 0.15s, cross-entropy: 206.04
# Epoch 33:	########################################	elapsed: 0.14s, cross-entropy: 206.04
# Epoch 34:	########################################	elapsed: 0.15s, cross-entropy: 206.04
# Epoch 35:	########################################	elapsed: 0.14s, cross-entropy: 206.04
# Epoch 36:	########################################	elapsed: 0.14s, cross-entropy: 206.04
# Epoch 37:	########################################	elapsed: 0.14s, cross-entropy: 206.03
# Epoch 38:	########################################	elapsed: 0.14s, cross-entropy: 206.03
# Epoch 39:	########################################	elapsed: 0.14s, cross-entropy: 206.03
# Epoch 40:	########################################	elapsed: 0.14s, cross-entropy: 206.03
# Epoch 41:	########################################	elapsed: 0.15s, cross-entropy: 206.03
# Epoch 42:	########################################	elapsed: 0.14s, cross-entropy: 206.03
# Epoch 43:	########################################	elapsed: 0.14s, cross-entropy: 206.02
# Epoch 44:	########################################	elapsed: 0.14s, cross-entropy: 206.02
# Epoch 45:	########################################	elapsed: 0.14s, cross-entropy: 206.02
# Epoch 46:	########################################	elapsed: 0.14s, cross-entropy: 206.02
# Epoch 47:	########################################	elapsed: 0.15s, cross-entropy: 206.02
# Epoch 48:	########################################	elapsed: 0.14s, cross-entropy: 206.02
# Epoch 49:	########################################	elapsed: 0.15s, cross-entropy: 206.01
# Epoch 50:	########################################	elapsed: 0.14s, cross-entropy: 206.01
# Training finished!
# <h3>Input layer filters in the plain AE</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3595734603.py:67: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
# <h3>Input minibatch</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3943962568.py:17: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   tiles(np.reshape(validation_set[: 8 * 24, :-1], newshape=(8, 24, 28, 28)))
# <h3>Plain AE reconstructions</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3943962568.py:20: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   ae_reconstructions = np.reshape(
# <h3>DBN training</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = minibatch @ rbm.W[:, :-1]
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:10: RuntimeWarning: overflow encountered in matmul
#   z = minibatch @ rbm.W[:, :-1]
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = minibatch @ rbm.W[:, :-1]
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:16: RuntimeWarning: divide by zero encountered in matmul
#   negative_hidden @ rbm.W[:-1, :].T, stochastic=True
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:16: RuntimeWarning: overflow encountered in matmul
#   negative_hidden @ rbm.W[:-1, :].T, stochastic=True
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:16: RuntimeWarning: invalid value encountered in matmul
#   negative_hidden @ rbm.W[:-1, :].T, stochastic=True
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = negative_visible @ rbm.W[:, :-1]
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:18: RuntimeWarning: overflow encountered in matmul
#   z = negative_visible @ rbm.W[:, :-1]
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = negative_visible @ rbm.W[:, :-1]
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:26: RuntimeWarning: divide by zero encountered in matmul
#   (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:26: RuntimeWarning: overflow encountered in matmul
#   (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:26: RuntimeWarning: invalid value encountered in matmul
#   (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:29: RuntimeWarning: divide by zero encountered in matmul
#   (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:29: RuntimeWarning: overflow encountered in matmul
#   (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:29: RuntimeWarning: invalid value encountered in matmul
#   (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.12s, reconstruction error: 31.66
# Epoch 2:	###########################
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:45: RuntimeWarning: divide by zero encountered in matmul
#   hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:45: RuntimeWarning: overflow encountered in matmul
#   hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:45: RuntimeWarning: invalid value encountered in matmul
#   hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:48: RuntimeWarning: divide by zero encountered in matmul
#   visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:48: RuntimeWarning: overflow encountered in matmul
#   visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/4184473067.py:48: RuntimeWarning: invalid value encountered in matmul
#   visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
# #############	elapsed: 0.13s, reconstruction error: 24.76
# Epoch 3:	########################################	elapsed: 0.11s, reconstruction error: 21.30
# Epoch 4:	########################################	elapsed: 0.13s, reconstruction error: 19.01
# Epoch 5:	########################################	elapsed: 0.11s, reconstruction error: 17.67
# Epoch 6:	########################################	elapsed: 0.12s, reconstruction error: 15.37
# Epoch 7:	########################################	elapsed: 0.12s, reconstruction error: 13.77
# Epoch 8:	########################################	elapsed: 0.12s, reconstruction error: 12.76
# Epoch 9:	########################################	elapsed: 0.13s, reconstruction error: 11.94
# Epoch 10:	########################################	elapsed: 0.12s, reconstruction error: 11.47
# Epoch 11:	########################################	elapsed: 0.11s, reconstruction error: 11.04
# Epoch 12:	########################################	elapsed: 0.11s, reconstruction error: 10.90
# Epoch 13:	########################################	elapsed: 0.11s, reconstruction error: 10.80
# Epoch 14:	########################################	elapsed: 0.12s, reconstruction error: 10.60
# Epoch 15:	########################################	elapsed: 0.12s, reconstruction error: 10.41
# Epoch 16:	########################################	elapsed: 0.11s, reconstruction error: 10.10
# Epoch 17:	########################################	elapsed: 0.12s, reconstruction error: 9.89
# Epoch 18:	########################################	elapsed: 0.12s, reconstruction error: 9.92
# Epoch 19:	########################################	elapsed: 0.12s, reconstruction error: 9.74
# Epoch 20:	########################################	elapsed: 0.12s, reconstruction error: 9.81
# Epoch 21:	########################################	elapsed: 0.11s, reconstruction error: 9.66
# Epoch 22:	########################################	elapsed: 0.12s, reconstruction error: 9.55
# Epoch 23:	########################################	elapsed: 0.12s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 0.11s, reconstruction error: 9.48
# Epoch 25:	########################################	elapsed: 0.11s, reconstruction error: 9.31
# Epoch 26:	########################################	elapsed: 0.11s, reconstruction error: 9.33
# Epoch 27:	########################################	elapsed: 0.12s, reconstruction error: 9.35
# Epoch 28:	########################################	elapsed: 0.12s, reconstruction error: 9.30
# Epoch 29:	########################################	elapsed: 0.13s, reconstruction error: 9.29
# Epoch 30:	########################################	elapsed: 0.12s, reconstruction error: 9.22
# Epoch 31:	########################################	elapsed: 0.11s, reconstruction error: 9.15
# Epoch 32:	########################################	elapsed: 0.12s, reconstruction error: 9.05
# Epoch 33:	########################################	elapsed: 0.12s, reconstruction error: 9.03
# Epoch 34:	########################################	elapsed: 0.12s, reconstruction error: 9.03
# Epoch 35:	########################################	elapsed: 0.12s, reconstruction error: 8.96
# Epoch 36:	########################################	elapsed: 0.12s, reconstruction error: 9.06
# Epoch 37:	########################################	elapsed: 0.11s, reconstruction error: 8.86
# Epoch 38:	########################################	elapsed: 0.12s, reconstruction error: 8.77
# Epoch 39:	########################################	elapsed: 0.12s, reconstruction error: 8.90
# Epoch 40:	########################################	elapsed: 0.12s, reconstruction error: 8.90
# Epoch 41:	########################################	elapsed: 0.13s, reconstruction error: 8.77
# Epoch 42:	########################################	elapsed: 0.11s, reconstruction error: 8.87
# Epoch 43:	########################################	elapsed: 0.12s, reconstruction error: 8.79
# Epoch 44:	########################################	elapsed: 0.12s, reconstruction error: 8.79
# Epoch 45:	########################################	elapsed: 0.12s, reconstruction error: 8.71
# Epoch 46:	########################################	elapsed: 0.11s, reconstruction error: 8.77
# Epoch 47:	########################################	elapsed: 0.10s, reconstruction error: 8.77
# Epoch 48:	########################################	elapsed: 0.12s, reconstruction error: 8.70
# Epoch 49:	########################################	elapsed: 0.12s, reconstruction error: 8.82
# Epoch 50:	########################################	elapsed: 0.12s, reconstruction error: 8.67
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.06s, reconstruction error: 20.74
# Epoch 2:	######################
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/1804994209.py:3: RuntimeWarning: divide by zero encountered in matmul
#   visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/1804994209.py:3: RuntimeWarning: overflow encountered in matmul
#   visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/1804994209.py:3: RuntimeWarning: invalid value encountered in matmul
#   visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
# ##################	elapsed: 0.05s, reconstruction error: 15.88
# Epoch 3:	########################################	elapsed: 0.05s, reconstruction error: 13.84
# Epoch 4:	########################################	elapsed: 0.05s, reconstruction error: 12.45
# Epoch 5:	########################################	elapsed: 0.08s, reconstruction error: 11.42
# Epoch 6:	########################################	elapsed: 0.05s, reconstruction error: 9.58
# Epoch 7:	########################################	elapsed: 0.05s, reconstruction error: 8.25
# Epoch 8:	########################################	elapsed: 0.04s, reconstruction error: 7.57
# Epoch 9:	########################################	elapsed: 0.05s, reconstruction error: 7.15
# Epoch 10:	########################################	elapsed: 0.06s, reconstruction error: 6.91
# Epoch 11:	########################################	elapsed: 0.06s, reconstruction error: 6.72
# Epoch 12:	########################################	elapsed: 0.05s, reconstruction error: 6.50
# Epoch 13:	########################################	elapsed: 0.05s, reconstruction error: 6.39
# Epoch 14:	########################################	elapsed: 0.05s, reconstruction error: 6.09
# Epoch 15:	########################################	elapsed: 0.05s, reconstruction error: 6.14
# Epoch 16:	########################################	elapsed: 0.05s, reconstruction error: 5.95
# Epoch 17:	########################################	elapsed: 0.05s, reconstruction error: 5.87
# Epoch 18:	########################################	elapsed: 0.05s, reconstruction error: 5.80
# Epoch 19:	########################################	elapsed: 0.05s, reconstruction error: 5.84
# Epoch 20:	########################################	elapsed: 0.05s, reconstruction error: 5.75
# Epoch 21:	########################################	elapsed: 0.05s, reconstruction error: 5.76
# Epoch 22:	########################################	elapsed: 0.04s, reconstruction error: 5.67
# Epoch 23:	########################################	elapsed: 0.04s, reconstruction error: 5.61
# Epoch 24:	########################################	elapsed: 0.06s, reconstruction error: 5.67
# Epoch 25:	########################################	elapsed: 0.06s, reconstruction error: 5.58
# Epoch 26:	########################################	elapsed: 0.05s, reconstruction error: 5.52
# Epoch 27:	########################################	elapsed: 0.05s, reconstruction error: 5.40
# Epoch 28:	########################################	elapsed: 0.06s, reconstruction error: 5.36
# Epoch 29:	########################################	elapsed: 0.06s, reconstruction error: 5.35
# Epoch 30:	########################################	elapsed: 0.06s, reconstruction error: 5.43
# Epoch 31:	########################################	elapsed: 0.05s, reconstruction error: 5.39
# Epoch 32:	########################################	elapsed: 0.06s, reconstruction error: 5.34
# Epoch 33:	########################################	elapsed: 0.05s, reconstruction error: 5.23
# Epoch 34:	########################################	elapsed: 0.05s, reconstruction error: 5.30
# Epoch 35:	########################################	elapsed: 0.05s, reconstruction error: 5.22
# Epoch 36:	########################################	elapsed: 0.05s, reconstruction error: 5.22
# Epoch 37:	########################################	elapsed: 0.05s, reconstruction error: 5.17
# Epoch 38:	########################################	elapsed: 0.06s, reconstruction error: 5.20
# Epoch 39:	########################################	elapsed: 0.06s, reconstruction error: 5.20
# Epoch 40:	########################################	elapsed: 0.05s, reconstruction error: 5.17
# Epoch 41:	########################################	elapsed: 0.06s, reconstruction error: 5.19
# Epoch 42:	########################################	elapsed: 0.06s, reconstruction error: 5.15
# Epoch 43:	########################################	elapsed: 0.05s, reconstruction error: 5.13
# Epoch 44:	########################################	elapsed: 0.05s, reconstruction error: 5.08
# Epoch 45:	########################################	elapsed: 0.04s, reconstruction error: 5.07
# Epoch 46:	########################################	elapsed: 0.05s, reconstruction error: 5.10
# Epoch 47:	########################################	elapsed: 0.05s, reconstruction error: 5.10
# Epoch 48:	########################################	elapsed: 0.05s, reconstruction error: 5.07
# Epoch 49:	########################################	elapsed: 0.06s, reconstruction error: 5.08
# Epoch 50:	########################################	elapsed: 0.05s, reconstruction error: 5.07
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.03s, reconstruction error: 14.30
# Epoch 2:	########################################	elapsed: 0.03s, reconstruction error: 10.58
# Epoch 3:	########################################	elapsed: 0.04s, reconstruction error: 9.30
# Epoch 4:	########################################	elapsed: 0.04s, reconstruction error: 8.31
# Epoch 5:	########################################	elapsed: 0.04s, reconstruction error: 7.60
# Epoch 6:	########################################	elapsed: 0.04s, reconstruction error: 6.39
# Epoch 7:	########################################	elapsed: 0.04s, reconstruction error: 5.63
# Epoch 8:	########################################	elapsed: 0.04s, reconstruction error: 5.32
# Epoch 9:	########################################	elapsed: 0.03s, reconstruction error: 5.04
# Epoch 10:	########################################	elapsed: 0.03s, reconstruction error: 4.93
# Epoch 11:	########################################	elapsed: 0.04s, reconstruction error: 4.79
# Epoch 12:	########################################	elapsed: 0.04s, reconstruction error: 4.57
# Epoch 13:	########################################	elapsed: 0.03s, reconstruction error: 4.49
# Epoch 14:	########################################	elapsed: 0.04s, reconstruction error: 4.55
# Epoch 15:	########################################	elapsed: 0.03s, reconstruction error: 4.45
# Epoch 16:	########################################	elapsed: 0.03s, reconstruction error: 4.41
# Epoch 17:	########################################	elapsed: 0.03s, reconstruction error: 4.37
# Epoch 18:	########################################	elapsed: 0.03s, reconstruction error: 4.31
# Epoch 19:	########################################	elapsed: 0.03s, reconstruction error: 4.25
# Epoch 20:	########################################	elapsed: 0.04s, reconstruction error: 4.22
# Epoch 21:	########################################	elapsed: 0.03s, reconstruction error: 4.11
# Epoch 22:	########################################	elapsed: 0.04s, reconstruction error: 4.22
# Epoch 23:	########################################	elapsed: 0.04s, reconstruction error: 4.12
# Epoch 24:	########################################	elapsed: 0.04s, reconstruction error: 4.13
# Epoch 25:	########################################	elapsed: 0.04s, reconstruction error: 4.06
# Epoch 26:	########################################	elapsed: 0.03s, reconstruction error: 4.12
# Epoch 27:	########################################	elapsed: 0.04s, reconstruction error: 4.07
# Epoch 28:	########################################	elapsed: 0.04s, reconstruction error: 4.07
# Epoch 29:	########################################	elapsed: 0.04s, reconstruction error: 4.13
# Epoch 30:	########################################	elapsed: 0.04s, reconstruction error: 4.13
# Epoch 31:	########################################	elapsed: 0.03s, reconstruction error: 4.05
# Epoch 32:	########################################	elapsed: 0.03s, reconstruction error: 4.03
# Epoch 33:	########################################	elapsed: 0.03s, reconstruction error: 4.02
# Epoch 34:	########################################	elapsed: 0.03s, reconstruction error: 4.05
# Epoch 35:	########################################	elapsed: 0.03s, reconstruction error: 3.99
# Epoch 36:	########################################	elapsed: 0.04s, reconstruction error: 4.06
# Epoch 37:	########################################	elapsed: 0.04s, reconstruction error: 4.04
# Epoch 38:	########################################	elapsed: 0.03s, reconstruction error: 3.97
# Epoch 39:	########################################	elapsed: 0.04s, reconstruction error: 4.03
# Epoch 40:	########################################	elapsed: 0.04s, reconstruction error: 3.99
# Epoch 41:	########################################	elapsed: 0.03s, reconstruction error: 3.94
# Epoch 42:	########################################	elapsed: 0.04s, reconstruction error: 4.02
# Epoch 43:	########################################	elapsed: 0.03s, reconstruction error: 3.90
# Epoch 44:	########################################	elapsed: 0.04s, reconstruction error: 3.90
# Epoch 45:	########################################	elapsed: 0.03s, reconstruction error: 3.99
# Epoch 46:	########################################	elapsed: 0.04s, reconstruction error: 3.92
# Epoch 47:	########################################	elapsed: 0.03s, reconstruction error: 3.98
# Epoch 48:	########################################	elapsed: 0.03s, reconstruction error: 3.96
# Epoch 49:	########################################	elapsed: 0.03s, reconstruction error: 3.96
# Epoch 50:	########################################	elapsed: 0.03s, reconstruction error: 3.93
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.02s, reconstruction error: 11.46
# Epoch 2:	########################################	elapsed: 0.03s, reconstruction error: 10.06
# Epoch 3:	########################################	elapsed: 0.03s, reconstruction error: 9.19
# Epoch 4:	########################################	elapsed: 0.03s, reconstruction error: 8.83
# Epoch 5:	########################################	elapsed: 0.03s, reconstruction error: 8.56
# Epoch 6:	########################################	elapsed: 0.03s, reconstruction error: 8.19
# Epoch 7:	########################################	elapsed: 0.02s, reconstruction error: 8.35
# Epoch 8:	########################################	elapsed: 0.03s, reconstruction error: 8.54
# Epoch 9:	########################################	elapsed: 0.03s, reconstruction error: 8.69
# Epoch 10:	########################################	elapsed: 0.03s, reconstruction error: 8.84
# Epoch 11:	########################################	elapsed: 0.03s, reconstruction error: 8.97
# Epoch 12:	########################################	elapsed: 0.03s, reconstruction error: 9.04
# Epoch 13:	########################################	elapsed: 0.03s, reconstruction error: 9.12
# Epoch 14:	########################################	elapsed: 0.03s, reconstruction error: 9.18
# Epoch 15:	########################################	elapsed: 0.02s, reconstruction error: 9.23
# Epoch 16:	########################################	elapsed: 0.03s, reconstruction error: 9.22
# Epoch 17:	########################################	elapsed: 0.03s, reconstruction error: 9.29
# Epoch 18:	########################################	elapsed: 0.02s, reconstruction error: 9.32
# Epoch 19:	########################################	elapsed: 0.03s, reconstruction error: 9.31
# Epoch 20:	########################################	elapsed: 0.02s, reconstruction error: 9.34
# Epoch 21:	########################################	elapsed: 0.03s, reconstruction error: 9.36
# Epoch 22:	########################################	elapsed: 0.02s, reconstruction error: 9.39
# Epoch 23:	########################################	elapsed: 0.03s, reconstruction error: 9.40
# Epoch 24:	########################################	elapsed: 0.03s, reconstruction error: 9.39
# Epoch 25:	########################################	elapsed: 0.03s, reconstruction error: 9.43
# Epoch 26:	########################################	elapsed: 0.03s, reconstruction error: 9.40
# Epoch 27:	########################################	elapsed: 0.03s, reconstruction error: 9.45
# Epoch 28:	########################################	elapsed: 0.03s, reconstruction error: 9.46
# Epoch 29:	########################################	elapsed: 0.02s, reconstruction error: 9.49
# Epoch 30:	########################################	elapsed: 0.03s, reconstruction error: 9.48
# Epoch 31:	########################################	elapsed: 0.03s, reconstruction error: 9.51
# Epoch 32:	########################################	elapsed: 0.02s, reconstruction error: 9.53
# Epoch 33:	########################################	elapsed: 0.02s, reconstruction error: 9.56
# Epoch 34:	########################################	elapsed: 0.02s, reconstruction error: 9.58
# Epoch 35:	########################################	elapsed: 0.02s, reconstruction error: 9.57
# Epoch 36:	########################################	elapsed: 0.03s, reconstruction error: 9.59
# Epoch 37:	########################################	elapsed: 0.03s, reconstruction error: 9.60
# Epoch 38:	########################################	elapsed: 0.02s, reconstruction error: 9.64
# Epoch 39:	########################################	elapsed: 0.03s, reconstruction error: 9.67
# Epoch 40:	########################################	elapsed: 0.03s, reconstruction error: 9.68
# Epoch 41:	########################################	elapsed: 0.03s, reconstruction error: 9.68
# Epoch 42:	########################################	elapsed: 0.03s, reconstruction error: 9.69
# Epoch 43:	########################################	elapsed: 0.03s, reconstruction error: 9.69
# Epoch 44:	########################################	elapsed: 0.05s, reconstruction error: 9.72
# Epoch 45:	########################################	elapsed: 0.06s, reconstruction error: 9.70
# Epoch 46:	########################################	elapsed: 0.04s, reconstruction error: 9.71
# Epoch 47:	########################################	elapsed: 0.03s, reconstruction error: 9.74
# Epoch 48:	########################################	elapsed: 0.02s, reconstruction error: 9.74
# Epoch 49:	########################################	elapsed: 0.02s, reconstruction error: 9.77
# Epoch 50:	########################################	elapsed: 0.03s, reconstruction error: 9.78
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3943962568.py:32: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   dbn_reconstructions = np.reshape(
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 136.65
#
# Epoch 1:	########################################	elapsed: 0.18s, cross-entropy: 106.80
# Epoch 2:	########################################	elapsed: 0.16s, cross-entropy: 103.18
# Epoch 3:	########################################	elapsed: 0.16s, cross-entropy: 101.32
# Epoch 4:	########################################	elapsed: 0.16s, cross-entropy: 99.95
# Epoch 5:	########################################	elapsed: 0.17s, cross-entropy: 98.97
# Epoch 6:	########################################	elapsed: 0.16s, cross-entropy: 98.27
# Epoch 7:	########################################	elapsed: 0.16s, cross-entropy: 97.73
# Epoch 8:	########################################	elapsed: 0.16s, cross-entropy: 97.22
# Epoch 9:	########################################	elapsed: 0.16s, cross-entropy: 96.69
# Epoch 10:	########################################	elapsed: 0.16s, cross-entropy: 96.21
# Epoch 11:	########################################	elapsed: 0.16s, cross-entropy: 95.84
# Epoch 12:	########################################	elapsed: 0.18s, cross-entropy: 95.56
# Epoch 13:	########################################	elapsed: 0.15s, cross-entropy: 95.29
# Epoch 14:	########################################	elapsed: 0.16s, cross-entropy: 95.23
# Epoch 15:	########################################	elapsed: 0.17s, cross-entropy: 95.39
# Epoch 16:	########################################	elapsed: 0.18s, cross-entropy: 94.83
# Epoch 17:	########################################	elapsed: 0.15s, cross-entropy: 94.12
# Epoch 18:	########################################	elapsed: 0.16s, cross-entropy: 93.89
# Epoch 19:	########################################	elapsed: 0.16s, cross-entropy: 93.75
# Epoch 20:	########################################	elapsed: 0.16s, cross-entropy: 93.77
# Epoch 21:	########################################	elapsed: 0.16s, cross-entropy: 94.05
# Epoch 22:	########################################	elapsed: 0.17s, cross-entropy: 93.27
# Epoch 23:	########################################	elapsed: 0.16s, cross-entropy: 92.90
# Epoch 24:	########################################	elapsed: 0.19s, cross-entropy: 93.07
# Epoch 25:	########################################	elapsed: 0.15s, cross-entropy: 93.03
# Epoch 26:	########################################	elapsed: 0.16s, cross-entropy: 92.98
# Epoch 27:	########################################	elapsed: 0.15s, cross-entropy: 92.95
# Epoch 28:	########################################	elapsed: 0.16s, cross-entropy: 94.01
# Epoch 29:	########################################	elapsed: 0.17s, cross-entropy: 92.98
# Epoch 30:	########################################	elapsed: 0.16s, cross-entropy: 92.71
# Epoch 31:	########################################	elapsed: 0.16s, cross-entropy: 91.92
# Epoch 32:	########################################	elapsed: 0.16s, cross-entropy: 91.67
# Epoch 33:	########################################	elapsed: 0.16s, cross-entropy: 91.87
# Epoch 34:	########################################	elapsed: 0.16s, cross-entropy: 92.92
# Epoch 35:	########################################	elapsed: 0.16s, cross-entropy: 94.06
# Epoch 36:	########################################	elapsed: 0.17s, cross-entropy: 94.61
# Epoch 37:	########################################	elapsed: 0.16s, cross-entropy: 92.82
# Epoch 38:	########################################	elapsed: 0.16s, cross-entropy: 91.66
# Epoch 39:	########################################	elapsed: 0.18s, cross-entropy: 91.56
# Epoch 40:	########################################	elapsed: 0.16s, cross-entropy: 91.75
# Epoch 41:	########################################	elapsed: 0.17s, cross-entropy: 92.63
# Epoch 42:	########################################	elapsed: 0.16s, cross-entropy: 92.68
# Epoch 43:	########################################	elapsed: 0.18s, cross-entropy: 91.85
# Epoch 44:	########################################	elapsed: 0.16s, cross-entropy: 92.75
# Epoch 45:	########################################	elapsed: 0.16s, cross-entropy: 96.22
# Epoch 46:	########################################	elapsed: 0.16s, cross-entropy: 95.65
# Epoch 47:	########################################	elapsed: 0.17s, cross-entropy: 92.56
# Epoch 48:	########################################	elapsed: 0.17s, cross-entropy: 92.35
# Epoch 49:	########################################	elapsed: 0.16s, cross-entropy: 93.13
# Epoch 50:	########################################	elapsed: 0.16s, cross-entropy: 93.09
# Training finished!
# <h3>First layer filters in the DBN</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3595734603.py:62: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# <h3>Input layer filters in the pretrained & finetuned AE</h3>
# <h3>Input minibatch</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3943962568.py:51: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   tiles(np.reshape(validation_set[: 8 * 24, :-1], newshape=(8, 24, 28, 28)))
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>
# /var/folders/8j/_nnvcqj93gvgk18wygygd9tw0000gn/T/ipykernel_51681/3943962568.py:57: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   ae_reconstructions = np.reshape(
